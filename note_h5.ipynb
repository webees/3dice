# %%
import os
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
FILE = 'ep335_loss0.285_acc0.965_vloss0.278_vacc0.972.h5'

model = tf.keras.models.load_model(FILE)
model.summary()
display(model.get_config())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                156
#
#  dense_1 (Dense)             (None, 58)                754
#
#  dense_2 (Dense)             (None, 60)                3540
#
#  dense_3 (Dense)             (None, 57)                3477
#
#  dense_4 (Dense)             (None, 57)                3306
#
#  dense_5 (Dense)             (None, 56)                3248
#
# ...
# Total params: 14,481
# Trainable params: 14,481
# Non-trainable params: 0
# _________________________________________________________________
# {'name': 'sequential',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 12),
#     'dtype': 'int32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'dense_input'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense',
#     'trainable': True,
# ...
